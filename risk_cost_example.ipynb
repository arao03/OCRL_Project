# %%
from RiskCost import RiskCost
import numpy as np
import matplotlib.pyplot as plt

# %%
myRiskCost = RiskCost(path_to_slopes="data/cuprite_slope.npy")

# %%
# Display slope map
plt.imshow(myRiskCost.slopes, cmap='hot', interpolation='nearest')
plt.show()

# %%
# Display cost map
plt.imshow(myRiskCost.cost, cmap='hot', interpolation='nearest')
plt.show()

# %%
# Display cost map
plt.imshow(myRiskCost.inflated_cost, cmap='hot', interpolation='nearest')
plt.show()

# %%
np.max(myRiskCost.slopes)
# Out:
# 89.97342
