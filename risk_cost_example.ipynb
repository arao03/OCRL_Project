# %%
from RiskCost import RiskCost
import numpy as np
import matplotlib.pyplot as plt

# %%
myRiskCost = RiskCost(path_to_slopes="data/cuprite_slope.npy")

# %%
# Display slope map
plt.imshow(myRiskCost.get_slope_array(), cmap='hot', interpolation='nearest')
plt.show()

# %%
# Display cost map
plt.imshow(myRiskCost.get_cost_array(), cmap='hot', interpolation='nearest')
plt.show()
